# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate example data
np.random.seed(42)  # for reproducibility
hours_studied = np.random.uniform(0, 10, 50)  # 50 data points for hours studied
test_scores = 2 * hours_studied + 5 + np.random.normal(0, 2, 50)  # linear relationship with noise

# Plot the data
plt.scatter(hours_studied, test_scores, label='Observed Data')
plt.title('Relationship between Hours Studied and Test Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Test Scores')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Reshape the data for sklearn
X = hours_studied.reshape(-1, 1)

# Fit the linear regression model
model = LinearRegression()
model.fit(X, test_scores)

# Make predictions
predictions = model.predict(X)

# Plot the data and the regression line
plt.scatter(hours_studied, test_scores, label='Observed Data')
plt.plot(hours_studied, predictions, color='red', label='Linear Regression Line')
plt.title('Linear Regression: Hours Studied vs. Test Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Test Scores')
plt.legend()
plt.show()
